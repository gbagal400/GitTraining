# %%
# !pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (1.64.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.47.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from google-genai) (3.13.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->google-genai) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.2)

# %%
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)

# sanity check: list models
for m in client.models.list():
    print(m.name)

# generate content
#response = client.models.generate_content(
#    model="gemini-1.5-flash",
#    contents="What is the meaning of life?")

#print(response.text)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025

# %%
# generate content
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is the meaning of life?")

print(response.text)
# Out:
# That is one of the oldest, deepest, and most personal questions humanity has ever asked!
#
# There is no single, universally agreed-upon answer, and that's perhaps the most important thing to understand. The "meaning of life" is something individuals, cultures, and philosophical traditions have grappled with for millennia, leading to a rich tapestry of perspectives.
#
# Here's a breakdown of common approaches to understanding the meaning of life:
#
# 1.  **No Inherent Meaning (Existentialism/Absurdism):**
#     *   **Core Idea:** Life, in and of itself, has no pre-ordained or universal meaning. We are born into an indifferent universe, and there's no divine plan or cosmic purpose laid out for us.
#     *   **Implication:** This can be seen as either terrifying or incredibly liberating.
#         *   **Existentialism:** Since there's no inherent meaning, it is *our responsibility* to create our own meaning through our choices, actions, and values. We are condemned to be free.
#         *   **Absurdism:** The human desire for meaning clashes with the silent indifference of the universe, creating an "absurd" condition. The meaning is in confronting this absurdity with defiance, joy, or rebellion (e.g., Sisyphus finding joy in pushing the boulder).
#
# 2.  **Meaning is Given by a Higher Power (Religious/Spiritual):**
#     *   **Core Idea:** Life has a purpose because it was created by a divine being or force, or is part of a spiritual journey.
#     *   **Examples:**
#         *   **Monotheistic Religions (Christianity, Islam, Judaism):** To serve God, fulfill His will, achieve salvation, live righteously, and contribute to His creation.
#         *   **Eastern Religions (Buddhism, Hinduism):** To achieve enlightenment, break the cycle of reincarnation (samsara), understand the nature of reality, or fulfill one's dharma (duty/purpose).
#     *   **Implication:** Meaning is discovered through faith, scripture, spiritual practice, and adherence to specific moral codes.
#
# 3.  **Meaning is Found in Specific Values/Experiences:**
#     *   **Core Idea:** While there might not be a grand, overarching meaning, life gains meaning through particular pursuits and states of being.
#     *   **Common examples include finding meaning in:**
#         *   **Love and Relationships:** Deep connections with family, friends, partners; compassion and empathy for others.
#         *   **Contribution and Service:** Making a positive impact on the world, helping others, working for a cause greater than oneself, leaving a legacy.
#         *   **Joy and Happiness:** Experiencing pleasure, beauty, wonder, and contentment; savoring life's moments.
#         *   **Knowledge and Understanding:** Learning, exploring, seeking truth, personal growth, self-actualization.
#         *   **Creativity and Expression:** Art, music, writing, innovation, bringing new things into existence.
#         *   **Overcoming Challenges:** Resilience, growth through adversity, finding strength in struggle.
#
# 4.  **Biological/Evolutionary Meaning:**
#     *   **Core Idea:** From a purely biological perspective, the "meaning" of life could be seen as survival and reproduction – the perpetuation of one's genes and species.
#     *   **Implication:** While this describes a fundamental function, most people would argue it doesn't fully capture the subjective human experience of "meaning."
#
# **How to Approach Your Own Meaning of Life:**
#
# Since there's no universal answer, the "meaning of life" often becomes a personal quest. Consider these questions:
#
# *   What gives you a sense of purpose or fulfillment?
# *   What values are most important to you?
# *   What do you truly care about?
# *   What makes you feel alive?
# *   How do you want to spend your time and energy?
# *   What kind of legacy do you want to leave, if any?
#
# Ultimately, the meaning of life is likely **what you make it.** It's a continuous process of discovery, reflection, and action that can evolve throughout your life. It's often not a single answer, but a collection of values, experiences, and purposes that give your existence depth and significance.
