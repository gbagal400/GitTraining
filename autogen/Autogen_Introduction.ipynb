# %%
# !pip install pyautogen==0.2.28 google-generativeai nest_asyncio

# %%
import os
from google.colab import userdata
from google import genai
# Load API key from Colab Secrets into environment variable
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %%
import google.generativeai as genai

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

def gemini_llm(prompt):
    model = genai.GenerativeModel("gemini-2.5-flash-lite")
    response = model.generate_content(prompt)
    return response.text

# %%
class GeminiAgent:
    def __init__(self, name):
        self.name = name

    def generate_reply(self, message):
        print(f"\n[{self.name}] thinking...")
        response = gemini_llm(message)
        print(f"\n[{self.name}]:\n{response}")
        return response

# %%
assistant = GeminiAgent("Assistant")
planner = GeminiAgent("Planner")

# %%
def run_agents(task):
    print("\n🟢 USER TASK:\n", task)

    # Step 1: Planning
    plan = planner.generate_reply(f"Break this task into steps:\n{task}")

    # Step 2: Execution
    result = assistant.generate_reply(f"Execute this plan:\n{plan}")

    print("\n✅ FINAL OUTPUT:\n", result)

# %%
run_agents("Write a Python program to compute Fibonacci numbers up to 10")
# Out:
# 🟢 USER TASK:
#  Write a Python program to compute Fibonacci numbers up to 10
#
# [Planner] thinking...
#
# [Planner]:
# Here's a breakdown of the task "Write a Python program to compute Fibonacci numbers up to 10" into steps:
#
# **Phase 1: Understanding the Problem**
#
# 1.  **Define the Fibonacci Sequence:** Understand what the Fibonacci sequence is. It starts with 0 and 1, and each subsequent number is the sum of the two preceding ones (e.g., 0, 1, 1, 2, 3, 5, 8, 13, ...).
# 2.  **Identify the Goal:** The program needs to *compute* and *display* Fibonacci numbers.
# 3.  **Determine the Limit:** The program should stop computing once it reaches or exceeds the number 10. This means we need to find Fibonacci numbers that are less than or equal to 10.
#
# **Phase 2: Planning the Approach**
#
# 4.  **Choose a Method for Calculation:**
# ...
