# %%
import random
import string

# %%
# ----------------------------
# Genetic Algorithm Components
# ----------------------------

TARGET = "HELLO WORLD"
POP_SIZE = 100
MUTATION_RATE = 0.01
GENERATIONS = 5000

# %%
# Generate a random character
def random_char():
    return random.choice(string.ascii_uppercase + " ")


# Create a random chromosome (a string)
def create_chromosome():
    return "".join(random_char() for _ in range(len(TARGET)))


# Fitness function: number of matching characters
def fitness(chromosome):
    score = 0
    for c1, c2 in zip(chromosome, TARGET):
        if c1 == c2:
            score += 1
    return score

# %%
# Selection: pick two parents based on fitness (tournament selection)
def selection(population):
    p1 = random.choice(population)
    p2 = random.choice(population)
    return p1 if fitness(p1) > fitness(p2) else p2


# Crossover: single-point crossover
def crossover(parent1, parent2):
    point = random.randint(1, len(TARGET) - 1)
    child = parent1[:point] + parent2[point:]
    return child


# Mutation: randomly change characters
def mutate(chromosome):
    chromosome_list = list(chromosome)
    for i in range(len(chromosome_list)):
        if random.random() < MUTATION_RATE:
            chromosome_list[i] = random_char()
    return "".join(chromosome_list)

# %%
# ----------------------------
# Genetic Algorithm Workflow
# ----------------------------

# Step 1: Initialize population
population = [create_chromosome() for _ in range(POP_SIZE)]

for generation in range(GENERATIONS):

    # Step 2: Calculate fitness for all
    population = sorted(population, key=fitness, reverse=True)

    # Print best solution every 100 generations
    best = population[0]
    print(f"Gen {generation}: {best}  Fitness = {fitness(best)}")

    if fitness(best) == len(TARGET):
        print("\nTarget reached!")
        break

    # Step 3: Selection & reproduction
    new_population = []

    for _ in range(POP_SIZE):
        parent1 = selection(population)
        parent2 = selection(population)

        # Step 4: Crossover
        child = crossover(parent1, parent2)

        # Step 5: Mutation
        child = mutate(child)

        new_population.append(child)

    # Step 6: New generation
    population = new_population

print("\nFinal Result:", best)
# Out:
# Gen 0: ELZ OSIORN   Fitness = 3
# Gen 1: WEN OSIORN   Fitness = 4
# Gen 2: WEN OSIORUS  Fitness = 4
# Gen 3: FQLLNICOWIZ  Fitness = 3
# Gen 4: FQLLNICOSVW  Fitness = 3
# Gen 5: IK LNSIORJD  Fitness = 4
# Gen 6: WEEDFBWORYD  Fitness = 5
# Gen 7: WELLP YSVWD  Fitness = 5
# Gen 8: WELLPBWORN   Fitness = 6
# Gen 9: WELLPBWORND  Fitness = 7
# Gen 10: WELLN NORJD  Fitness = 7
# Gen 11: JELLP IORND  Fitness = 7
# Gen 12: FELLN CORND  Fitness = 7
# Gen 13: FELLN WORJD  Fitness = 8
# Gen 14: FELLN WORJD  Fitness = 8
# Gen 15: FELLP WORJD  Fitness = 8
# Gen 16: JELLN WORJD  Fitness = 8
# Gen 17: GELLN WORJD  Fitness = 8
# Gen 18: WELLP WORJD  Fitness = 8
# Gen 19: WELLN WORJD  Fitness = 8
# Gen 20: GELLN WORJD  Fitness = 8
# Gen 21: JELLN WORJD  Fitness = 8
# Gen 22: WELLN WORCD  Fitness = 8
# Gen 23: GELLN WORJD  Fitness = 8
# Gen 24: GELLN WORLD  Fitness = 9
# Gen 25: GELLN WORLD  Fitness = 9
# Gen 26: EELLN WORLD  Fitness = 9
# Gen 27: JELLP WORLD  Fitness = 9
# Gen 28: JELLN WORLD  Fitness = 9
# Gen 29: JELLN WORLD  Fitness = 9
# Gen 30: JELLN WORLD  Fitness = 9
# Gen 31: JELLP WORLD  Fitness = 9
# Gen 32: JELLN WORLD  Fitness = 9
# Gen 33: JELLO WORLD  Fitness = 10
# Gen 34: JELLO WORLD  Fitness = 10
# Gen 35: JELLO WORLD  Fitness = 10
# Gen 36: JELLO WORLD  Fitness = 10
# Gen 37: JELLO WORLD  Fitness = 10
# Gen 38: GELLO WORLD  Fitness = 10
# Gen 39: JELLO WORLD  Fitness = 10
# Gen 40: JELLO WORLD  Fitness = 10
# Gen 41: GELLO WORLD  Fitness = 10
# Gen 42: GELLO WORLD  Fitness = 10
# Gen 43: HELLO WORLD  Fitness = 11
#
# Target reached!
#
# Final Result: HELLO WORLD
