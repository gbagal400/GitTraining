# %% [markdown]
# <a href="https://colab.research.google.com/github/gbagal400/GitTraining/blob/master/GEN_AI_23_FEB_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Sudo Code:

'''write the system prompt
def function_one()
	infinite while loop:
		get input from the user;
		format the input;
		create the full prompt using system+user;
		if user input == quit or exit:
			break;
		get the response from LLM;
		format the output;
		print the output;

main program
call the function_one;'''

# %%
import requests
# ============================================
# API KEY: Get your key from https://aicafe.hcl.com/AICafe/#/tutorials/api-docs
# IMPORTANT: Enter your API key in the GUI instead of hardcoding it here
# ============================================
API_KEY = "de2a2b65-f340-4900-8aed-25810c049f39"  # <-- Use the GUI to enter your key
# --- Endpoint config ---
API_URL = (
    "https://aicafe.hcl.com/AICafeService/api/v1/subscription/openai/"
    "deployments/gpt-4.1/chat/completions?api-version=2024-12-01-preview"
)
SYSTEM_PROMPT = """
You are a helpful AI agent.
- Answer clearly and concisely.
- Ask for clarification only when truly needed.
"""
def run_agent():
    print("Simple AI agent. Type 'quit' to exit.\n")
    while True:
        user_input = input("You: ").strip()
        if user_input.lower() in {"quit", "exit"}:
            print("Agent: Goodbye! 👋")
            break
        # Build request body (OpenAI-style)
        body = {
            "model": "gpt-4.1",
            "messages": [
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": user_input},
            ],
            "temperature": 0.7,
        }
        headers = {
            "api-key": API_KEY,
            "Content-Type": "application/json",
            "Accept": "application/json",
        }
        try:
            response = requests.post(API_URL, headers=headers, json=body, timeout=60)
            response.raise_for_status()
            data = response.json()
            agent_reply = data["choices"][0]["message"]["content"].strip()
            print(f"Agent: {agent_reply}\n")
        except Exception as e:
            print(f"Error: {e}")
if __name__ == "__main__":
    run_agent()
# Out:
# Simple AI agent. Type 'quit' to exit.
#
# You: Who is Ganpat Bagal
# Agent: Ganpat Bagal was an Indian social worker, journalist, and writer from Maharashtra. He is known for his contributions to social causes and literature in the Marathi language. Bagal was recognized for his work with the Padma Shri, one of India's highest civilian honors, in 1979.
#
# You: quit
# Agent: Goodbye! 👋
